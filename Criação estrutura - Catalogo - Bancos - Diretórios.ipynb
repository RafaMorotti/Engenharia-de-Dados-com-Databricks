# %%
# %sql
create catalog if not exists pipeline_bikes;

# %%
# %sql

create schema if not exists pipeline_bikes.zone_silver;
create schema if not exists pipeline_bikes.zone_bronze;
create schema if not exists pipeline_bikes.zone_gold;

# %%
# %sql

create volume if not exists pipeline_bikes.zone_bronze.volume_bronze;
create volume if not exists pipeline_bikes.zone_silver.volume_silver;
create volume if not exists pipeline_bikes.zone_gold.volume_gold;
